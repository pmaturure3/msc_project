# %%
import sys
# !{sys.executable} -m pip install pandas
# !{sys.executable} -m pip install matplotlib
# !{sys.executable} -m pip install numpy

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
phishing_01= pd.read_csv('MendelayPhishingWebsitesDatasetSept2020.csv')

# source for Dataset.csv https://data.mendeley.com/datasets/6tm2d6sz7p/1
phishing_02= pd.read_csv('Dataset.csv')

# source https://www.mdpi.com/2076-3417/13/24/13269 ""
phishing_03_train= pd.read_csv('phishing_dataset_train.csv')
phishing_02_test= pd.read_csv('phishing_dataset_test.csv')

# %%
phishing_02
# Out:
#         Type  url_length  number_of_dots_in_url  \
# 0          0          37                      2
# 1          1          70                      5
# 2          0          42                      2
# 3          0          46                      2
# 4          0          51                      3
# ...      ...         ...                    ...
# 247945     0          42                      1
# 247946     0          42                      2
# 247947     1          33                      2
# 247948     1          83                      1
# 247949     0          34                      3
#
#         having_repeated_digits_in_url  number_of_digits_in_url  \
# 0                                   0                        0
# 1                                   0                        0
# 2                                   0                        6
# 3                                   0                        0
# 4                                   0                        0
# ...

# %%
phishing_03_train
# Out:
#      domain_similarity  url_length  http_protocol  num_dot  num_slash  \
# 0                 0.89          29              1        1          0
# 1                 0.88          28              1        1          0
# 2                 0.87          35              1        0          0
# 3                 0.49          64              1        1          3
# 4                 0.83          23              1        1          0
# ..                 ...         ...            ...      ...        ...
# 695               0.88          27              1        2          0
# 696               0.39          48              0        1          1
# 697               1.00          23              1        0          0
# 698               1.00          18              1        0          0
# 699               0.36          60              1        0          3
#
#      num_double_slash  num_hyphen  num_underscore  num_equal  num_paranthesis  \
# ...
