# %%
import sys
# !{sys.executable} -m pip install pandas
# !{sys.executable} -m pip install matplotlib
# !{sys.executable} -m pip install numpy

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
= pd.read_csv('phsm-severity-data.csv')
